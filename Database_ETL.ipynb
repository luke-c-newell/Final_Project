# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

# %%
#  Import and read the owid-covid-data.csv.
raw_covid_df = pd.read_csv("Resources/owid-covid-data.csv")
raw_covid_df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
subset_covid = raw_covid_df[['continent', 'location', 'date', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'total_tests_per_thousand','new_tests','new_tests_per_thousand','positive_rate', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'population','median_age', 'aged_65_older', 'aged_70_older', 'cardiovasc_death_rate', 'diabetes_prevalence', 'life_expectancy']]
subset_covid
# Out:
#       continent     location       date  total_cases_per_million  \
# 0          Asia  Afghanistan  2/24/2020                    0.026
# 1          Asia  Afghanistan  2/25/2020                    0.026
# 2          Asia  Afghanistan  2/26/2020                    0.026
# 3          Asia  Afghanistan  2/27/2020                    0.026
# 4          Asia  Afghanistan  2/28/2020                    0.026
# ...         ...          ...        ...                      ...
# 75553    Africa     Zimbabwe  3/13/2021                 2453.824
# 75554    Africa     Zimbabwe  3/14/2021                 2454.698
# 75555    Africa     Zimbabwe  3/15/2021                 2456.044
# 75556    Africa     Zimbabwe  3/16/2021                 2458.130
# 75557    Africa     Zimbabwe  3/17/2021                 2459.273
#
#        new_cases_per_million  total_deaths_per_million  \
# 0                      0.026                       NaN
# 1                      0.000                       NaN
# 2                      0.000                       NaN
# 3                      0.000                       NaN
# 4                      0.000                       NaN
# ...                      ...                       ...
# 75553                  3.230                   100.990
# 75554                  0.875                   101.124
# 75555                  1.346                   101.191
# 75556                  2.086                   101.393
# 75557                  1.144                   101.460
#
#        new_deaths_per_million  total_tests  total_tests_per_thousand  \
# 0                         NaN          NaN                       NaN
# 1                         NaN          NaN                       NaN
# 2                         NaN          NaN                       NaN
# 3                         NaN          NaN                       NaN
# 4                         NaN          NaN                       NaN
# ...                       ...          ...                       ...
# 75553                   0.336          NaN                       NaN
# 75554                   0.135          NaN                       NaN
# 75555                   0.067          NaN                       NaN
# 75556                   0.202          NaN                       NaN
# 75557                   0.067          NaN                       NaN
#
#        new_tests  ...  total_vaccinations  people_vaccinated  \
# 0            NaN  ...                 NaN                NaN
# 1            NaN  ...                 NaN                NaN
# 2            NaN  ...                 NaN                NaN
# 3            NaN  ...                 NaN                NaN
# 4            NaN  ...                 NaN                NaN
# ...          ...  ...                 ...                ...
# 75553        NaN  ...             36359.0            36359.0
# 75554        NaN  ...             36359.0            36359.0
# 75555        NaN  ...             37660.0            37660.0
# 75556        NaN  ...             39550.0            39550.0
# 75557        NaN  ...             39607.0            39607.0
#
#        people_fully_vaccinated  population  median_age  aged_65_older  \
# 0                          NaN  38928341.0        18.6          2.581
# 1                          NaN  38928341.0        18.6          2.581
# 2                          NaN  38928341.0        18.6          2.581
# 3                          NaN  38928341.0        18.6          2.581
# 4                          NaN  38928341.0        18.6          2.581
# ...                        ...         ...         ...            ...
# 75553                      NaN  14862927.0        19.6          2.822
# 75554                      NaN  14862927.0        19.6          2.822
# 75555                      NaN  14862927.0        19.6          2.822
# 75556                      NaN  14862927.0        19.6          2.822
# 75557                      NaN  14862927.0        19.6          2.822
#
#        aged_70_older  cardiovasc_death_rate  diabetes_prevalence  \
# 0              1.337                597.029                 9.59
# 1              1.337                597.029                 9.59
# 2              1.337                597.029                 9.59
# 3              1.337                597.029                 9.59
# 4              1.337                597.029                 9.59
# ...              ...                    ...                  ...
# 75553          1.882                307.846                 1.82
# 75554          1.882                307.846                 1.82
# 75555          1.882                307.846                 1.82
# 75556          1.882                307.846                 1.82
# 75557          1.882                307.846                 1.82
#
#        life_expectancy
# 0                64.83
# 1                64.83
# 2                64.83
# 3                64.83
# 4                64.83
# ...                ...
# 75553            61.49
# 75554            61.49
# 75555            61.49
# 75556            61.49
# 75557            61.49
#
# [75558 rows x 22 columns]

# %%
usa_covid = subset_covid[subset_covid['location'].str.contains('United States', na = False)]
usa_covid
# Out:
#            continent       location       date  total_cases_per_million  \
# 71614  North America  United States  1/22/2020                    0.003
# 71615  North America  United States  1/23/2020                    0.003
# 71616  North America  United States  1/24/2020                    0.006
# 71617  North America  United States  1/25/2020                    0.006
# 71618  North America  United States  1/26/2020                    0.015
# ...              ...            ...        ...                      ...
# 72030  North America  United States  3/13/2021                88822.713
# 72031  North America  United States  3/14/2021                88938.186
# 72032  North America  United States  3/15/2021                89109.330
# 72033  North America  United States  3/16/2021                89271.198
# 72034  North America  United States  3/17/2021                89447.874
#
#        new_cases_per_million  total_deaths_per_million  \
# 71614                    NaN                       NaN
# 71615                  0.000                       NaN
# 71616                  0.003                       NaN
# 71617                  0.000                       NaN
# 71618                  0.009                       NaN
# ...                      ...                       ...
# 72030                160.769                  1614.235
# 72031                115.473                  1615.963
# 72032                171.144                  1618.199
# 72033                161.869                  1622.084
# 72034                176.675                  1625.627
#
#        new_deaths_per_million  total_tests  total_tests_per_thousand  \
# 71614                     NaN          NaN                       NaN
# 71615                     NaN          NaN                       NaN
# 71616                     NaN          NaN                       NaN
# 71617                     NaN          NaN                       NaN
# 71618                     NaN          NaN                       NaN
# ...                       ...          ...                       ...
# 72030                   5.211          NaN                       NaN
# 72031                   1.728          NaN                       NaN
# 72032                   2.236          NaN                       NaN
# 72033                   3.885          NaN                       NaN
# 72034                   3.544          NaN                       NaN
#
#        new_tests  ...  total_vaccinations  people_vaccinated  \
# 71614        NaN  ...                 NaN                NaN
# 71615        NaN  ...                 NaN                NaN
# 71616        NaN  ...                 NaN                NaN
# 71617        NaN  ...                 NaN                NaN
# 71618        NaN  ...                 NaN                NaN
# ...          ...  ...                 ...                ...
# 72030        NaN  ...         105703501.0         68884011.0
# 72031        NaN  ...         107060274.0         69784210.0
# 72032        NaN  ...         109081860.0         71054445.0
# 72033        NaN  ...         110737856.0         72135616.0
# 72034        NaN  ...         113037627.0         73669956.0
#
#        people_fully_vaccinated   population  median_age  aged_65_older  \
# 71614                      NaN  331002647.0        38.3         15.413
# 71615                      NaN  331002647.0        38.3         15.413
# 71616                      NaN  331002647.0        38.3         15.413
# 71617                      NaN  331002647.0        38.3         15.413
# 71618                      NaN  331002647.0        38.3         15.413
# ...                        ...          ...         ...            ...
# 72030               36929777.0  331002647.0        38.3         15.413
# 72031               37459269.0  331002647.0        38.3         15.413
# 72032               38335432.0  331002647.0        38.3         15.413
# 72033               39042345.0  331002647.0        38.3         15.413
# 72034               39989196.0  331002647.0        38.3         15.413
#
#        aged_70_older  cardiovasc_death_rate  diabetes_prevalence  \
# 71614          9.732                151.089                10.79
# 71615          9.732                151.089                10.79
# 71616          9.732                151.089                10.79
# 71617          9.732                151.089                10.79
# 71618          9.732                151.089                10.79
# ...              ...                    ...                  ...
# 72030          9.732                151.089                10.79
# 72031          9.732                151.089                10.79
# 72032          9.732                151.089                10.79
# 72033          9.732                151.089                10.79
# 72034          9.732                151.089                10.79
#
#        life_expectancy
# 71614            78.86
# 71615            78.86
# 71616            78.86
# 71617            78.86
# 71618            78.86
# ...                ...
# 72030            78.86
# 72031            78.86
# 72032            78.86
# 72033            78.86
# 72034            78.86
#
# [421 rows x 22 columns]
